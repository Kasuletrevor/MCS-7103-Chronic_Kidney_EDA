# %%
import pandas as pd

# Load the dataset
file_path = 'kidney_disease.csv'
data = pd.read_csv(file_path)
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (400, 26)

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             329 non-null    float64
# ...

# %%
summary_statistics = data.describe(include='all')
summary_statistics
# Out:
#                 id         age          bp          sg          al  \
# count   400.000000  391.000000  388.000000  353.000000  354.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean    199.500000   51.483376   76.469072    1.017408    1.016949
# std     115.614301   17.169714   13.683637    0.005717    1.352679
# min       0.000000    2.000000   50.000000    1.005000    0.000000
# 25%      99.750000   42.000000   70.000000    1.010000    0.000000
# 50%     199.500000   55.000000   80.000000    1.020000    0.000000
# 75%     299.250000   64.500000   80.000000    1.020000    2.000000
# max     399.000000   90.000000  180.000000    1.025000    5.000000
#
#                 su     rbc      pc         pcc          ba  ...  pcv    wc  \
# count   351.000000     248     335         396         396  ...  330   295
# ...

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
missing_values.sort_values(ascending=False)
# Out:
# rbc               152
# rc                130
# wc                105
# pot                88
# sod                87
# pcv                70
# pc                 65
# hemo               52
# su                 49
# sg                 47
# al                 46
# bgr                44
# bu                 19
# sc                 17
# bp                 12
# age                 9
# ba                  4
# pcc                 4
# htn                 2
# dm                  2
# cad                 2
# ane                 1
# appet               1
# pe                  1
# id                  0
# classification      0
# dtype: int64

# %%
data_types = data.dtypes
data_types
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
# View the overall information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             329 non-null    float64
# ...

# %% [markdown]
# ## Investigating  Non-Numeric entries

# %%
unique_pcv = data['pcv'].unique()
unique_pcv
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
unique_wc = data['wc'].unique()
unique_wc
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
unique_rc = data['rc'].unique()
unique_rc
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '\t?', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
classification_values = data['classification'].value_counts()
classification_values
# Out:
# classification
# ckd       248
# notckd    150
# ckd\t       2
# Name: count, dtype: int64

# %%
# Cleaning erroneous entries in 'pcv', 'wc', 'rc', and 'classification' columns
data['pcv'] = data['pcv'].replace({'\t?': None, '\t43': '43'}).astype(float)
data['wc'] = data['wc'].replace({'\t6200': '6200', '\t?': None}).astype(float)
data['rc'] = data['rc'].replace({'\t?': None}).astype(float)
# data['classification'] = data['classification'].replace({'ckd\t': 'ckd'})

# %%
data['classification'] = data['classification'].replace({'ckd\t': 'ckd'})

# %%
# Checking the counts of each class in the target variable (classification)
target_class_counts = data['classification'].value_counts()

target_class_counts
# Out:
# classification
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x='classification', data=data)
plt.title('Distribution of Kidney Disease Classification')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='classification', y='age', data=data)
plt.title('Age Distribution by Kidney Disease Classification')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='classification', y='pcv', data=data)
plt.title('Packed Cell Volume (PCV) Distribution by Kidney Disease Classification')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='classification', y='bp', data=data)
plt.title('Blood Pressure Distribution by Kidney Disease Classification')
plt.show()

# %%
# Selecting only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = numeric_data.corr()

# Plotting the correlation matrix
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix for Numeric Variables')
plt.show()

# %%
# Extract pairs of variables with correlation above 0.7 or below -0.7
high_correlation_pairs = []

# Iterating through the correlation matrix to find high correlations
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        correlation_value = correlation_matrix.iloc[i, j]
        if abs(correlation_value) > 0.7:  # Correlation threshold
            high_correlation_pairs.append((
                correlation_matrix.columns[i],  # Variable 1
                correlation_matrix.columns[j],  # Variable 2
                correlation_value  # Correlation value
            ))

# Displaying high correlation pairs
high_correlation_pairs
# Out:
# [('bgr', 'su', 0.7178267668666227),
#  ('pcv', 'hemo', 0.8953817669928061),
#  ('rc', 'hemo', 0.798880246744564),
#  ('rc', 'pcv', 0.7916252713729907)]

# %%
# Imputation for numerical variables using median
data['age'].fillna(data['age'].median(), inplace=True)
data['bp'].fillna(data['bp'].median(), inplace=True)
data['sg'].fillna(data['sg'].median(), inplace=True)
data['al'].fillna(data['al'].median(), inplace=True)
data['su'].fillna(data['su'].median(), inplace=True)
data['bgr'].fillna(data['bgr'].median(), inplace=True)
data['bu'].fillna(data['bu'].median(), inplace=True)
data['sc'].fillna(data['sc'].median(), inplace=True)
data['sod'].fillna(data['sod'].median(), inplace=True)
data['pot'].fillna(data['pot'].median(), inplace=True)
data['hemo'].fillna(data['hemo'].median(), inplace=True)
data['pcv'].fillna(data['pcv'].median(), inplace=True)
data['wc'].fillna(data['wc'].median(), inplace=True)
data['rc'].fillna(data['rc'].median(), inplace=True)
# Out:
# id                  0
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                 0
# wc                  0
# rc                  0
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
# Imputation for categorical variables using the most frequent value (mode)
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
for column in categorical_columns:
    data[column].fillna(data[column].mode()[0], inplace=True)

# %%
# Checking again for any remaining missing values
missing_values_after_imputation = data.isnull().sum()

missing_values_after_imputation
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
# Classify columns into categorical and numerical in the current data
cat_cols = [col for col in data.columns if data[col].dtype == 'object']
num_cols = [col for col in data.columns if data[col].dtype != 'object']

# %%
# Display unique values in each categorical column to identify non-standard values
non_standard_values = {}
for col in cat_cols:
    unique_values = data[col].unique()
    non_standard_values[col] = unique_values
    print(f'{col} has {unique_values} values\n')

# Displaying the non-standard values to the user for review
non_standard_values
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# cad has ['no' 'yes' '\tno' nan] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has ['ckd' 'notckd'] values
# {'rbc': array([nan, 'normal', 'abnormal'], dtype=object),
#  'pc': array(['normal', 'abnormal', nan], dtype=object),
#  'pcc': array(['notpresent', 'present', nan], dtype=object),
#  'ba': array(['notpresent', 'present', nan], dtype=object),
#  'htn': array(['yes', 'no', nan], dtype=object),
#  'dm': array(['yes', 'no', ' yes', '\tno', '\tyes', nan], dtype=object),
#  'cad': array(['no', 'yes', '\tno', nan], dtype=object),
#  'appet': array(['good', 'poor', nan], dtype=object),
# ...

# %%
# View the specific values in the categorical columns
for col in cat_cols:
    print(f'{col} has {data[col].unique()} values\n')
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# cad has ['no' 'yes' '\tno' nan] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has ['ckd' 'notckd'] values

# %%
# Cleaning non-standard values in 'dm' and 'cad' columns
data['dm'] = data['dm'].str.strip().replace({'\tyes': 'yes', '\tno': 'no', ' yes': 'yes'})
data['cad'] = data['cad'].str.strip().replace({'\tno': 'no'})

# Verifying the cleaned values
cleaned_values = {
    'dm': data['dm'].unique(),
    'cad': data['cad'].unique()
}

cleaned_values
# Out:
# {'dm': array(['yes', 'no', nan], dtype=object),
#  'cad': array(['no', 'yes', nan], dtype=object)}

# %%
# Checking the count of values in each 'classification' and relevant categorical columns to inspect the grouping
classification_counts = data.groupby('classification').size()
classification_counts
# Out:
# classification
# ckd       250
# notckd    150
# dtype: int64

# %%
# Visualizations
plt.figure(figsize=(10, 6))
sns.catplot(data=data, x="classification", y="age", hue="dm", kind="swarm")
plt.title("Age Distribution by Classification and Diabetes Mellitus")
plt.show()

# %%
sns.catplot(data=data, x="classification", y="age", hue="htn", kind="swarm")
plt.title("Age Distribution by Classification and Hypertension")

plt.show()

# %%
sns.catplot(data=data, x="classification", y="age", hue="cad", kind="swarm")
plt.title("Age Distribution by Classification and Coronary Artery Disease")
plt.show()
